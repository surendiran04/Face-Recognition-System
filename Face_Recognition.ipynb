# %% [markdown]
# <a href="https://colab.research.google.com/github/surendiran04/Face-Recognition-System/blob/main/Face_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install flask flask_cors pymongo deepface opencv-python mediapipe python-dotenv pyngrok

# %%
# !nohup python app.py &

# %%
from flask import Flask
from flask_cors import CORS
from pyngrok import ngrok
import os

os.system("ngrok config add-authtoken ") # Add ur ngrok token from the ngrok website

faces_db_path = "faces_db"
if not os.path.exists(faces_db_path):
    os.makedirs(faces_db_path)

from google.colab import drive #Registering image will be stored in google drive - it'll prompt to give access to drive while running this cell
drive.mount('/content/drive')


app = Flask(__name__)
app.config["DEBUG"] = True


# ✅ Expose Public URL via Ngrok
public_url = ngrok.connect(5000).public_url
print(f"🚀 Public URL: {public_url}")

# %%
# !cat nohup.out

# %%
# !nohup python app.py > nohup.out 2>&1 &
